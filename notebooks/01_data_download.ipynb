# %%
import pandas as pd
import numpy as np
import yfinance as yf
import matplotlib.pyplot as plt
import os

plt.style.use("seaborn-v0_8")

# Create data folder if missing
os.makedirs("../data", exist_ok=True)

# %%
tickers = {
    "SP500": "^GSPC",
    "NASDAQ": "^IXIC",
    "STOXX50": "^STOXX50E",
    "FTSE100": "^FTSE"
}

start_date = "1985-01-01"
end_date = "2025-01-01"

# %%
data = {}

for name, ticker in tickers.items():
    df = yf.download(ticker, start=start_date, end=end_date)
    data[name] = df
    print(f"Downloaded: {name} - {df.shape[0]} rows")
# Out:
# /tmp/ipykernel_1293/1803475788.py:4: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, start=start_date, end=end_date)
# [*********************100%***********************]  1 of 1 completed
# /tmp/ipykernel_1293/1803475788.py:4: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, start=start_date, end=end_date)
# Downloaded: SP500 - 10080 rows
# [*********************100%***********************]  1 of 1 completed
# /tmp/ipykernel_1293/1803475788.py:4: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, start=start_date, end=end_date)
# Downloaded: NASDAQ - 10080 rows
# [*********************100%***********************]  1 of 1 completed
# /tmp/ipykernel_1293/1803475788.py:4: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, start=start_date, end=end_date)
# Downloaded: STOXX50 - 4452 rows
# [*********************100%***********************]  1 of 1 completed
# Downloaded: FTSE100 - 10103 rows

# %%
# quick plotting to check
plt.figure(figsize=(12,5))
plt.plot(data["SP500"]["Close"], label="S&P 500")
plt.title("S&P 500 - Closing Prices")
plt.legend()
plt.show()

# %%
for name, df in data.items():
    df.to_csv(f"../data/{name}.csv")
print("Files saved in /data.")
# Out:
# Files saved in /data.
